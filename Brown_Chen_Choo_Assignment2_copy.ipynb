# %% [markdown]
# # Task 2

# %%
# # clear unneeded folders
# classes = None
# with open("data/food-101/meta/classes.txt") as f:
#     classes = f.readlines()
# classes = [c.strip("\n") for c in classes]
# print(len(classes))
# classes.remove("hot_and_sour_soup")
# classes.remove("pork_chop")
# classes.remove("beef_tartare")
# classes.remove("crab_cakes")
# classes.remove("baby_back_ribs")
# classes.remove("guacamole")
# classes.remove("french_onion_soup")
# classes.remove("dumplings")
# classes.remove("sushi")
# classes.remove("cheesecake")
# print(len(classes))

# import os
# import shutil

# current_dir = os.getcwd()
# images_dir = os.path.join(current_dir, "data/Food10")
# for c in classes:
#     to_rm = os.path.join(images_dir, c)
#     shutil.rmtree(to_rm)

# %%
# import os
# import shutil
# current_dir = os.getcwd()
# train_dir = os.path.join(current_dir, "Food10")
# test_dir = os.path.join(current_dir, "FoodTest")

# # Separate train and test data
# with open("test.csv") as f:
#     test_images = f.readlines()[1:]
# test_images = [ti.strip("\n").split(",")[1].split("\\") for ti in test_images]
# test_images = ["/".join(ti[-2:]) for ti in test_images]

# for im in test_images:
#     shutil.move(os.path.join(train_dir, im), os.path.join(test_dir, im))

# # Food10 for training, FoodTest for testing

# %%
import matplotlib.pyplot as plt 
import numpy as np 
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras import layers 
from tensorflow.keras.models import Sequential
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774320687.873170    4495 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1774320687.873671    4495 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1774320687.992790    4495 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774320688.952945    4495 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1774320688.953456    4495 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
import os
current_dir = os.getcwd()
train_dir = os.path.join(current_dir, "Food10")
test_dir = os.path.join(current_dir, "FoodTest")

train = tf.keras.utils.image_dataset_from_directory( 
	train_dir, 
    validation_split=0.3, 
	subset="training", 
	seed=55,
	image_size=(224, 224), 
	batch_size=32) 

test = tf.keras.utils.image_dataset_from_directory( 
	train_dir, 
    validation_split=0.2, 
	subset="validation", 
	seed=55,
	image_size=(224, 224), 
	batch_size=32) 

class_names = train.class_names 
print(class_names)
# Out:
# Found 7500 files belonging to 10 classes.
# Using 5250 files for training.
# E0000 00:00:1774320689.152888    4495 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Found 7500 files belonging to 10 classes.
# Using 1500 files for validation.
# ['baby_back_ribs', 'beef_tartare', 'cheesecake', 'crab_cakes', 'dumplings', 'french_onion_soup', 'guacamole', 'hot_and_sour_soup', 'pork_chop', 'sushi']

# %%
# losses = [tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
#           tf.keras.losses.CategoricalCrossentropy(from_logits=True),
#           tf.keras.losses.CategoricalFocalCrossentropy(from_logits=True)]
# epoch_nums = [10, 50, 100]

# best_model = None
# best_test_accuracy = 0.0
# best_loss = None
# best_epochs = None

# try:
#     for loss in losses:
#         for epochs in epoch_nums:
#             model = Sequential([ 
#                 layers.Rescaling(1./255, input_shape=(224,224, 3)), 
#                 layers.Conv2D(16, 3, padding='same', activation='relu'), 
#                 layers.MaxPooling2D(), 
#                 layers.Conv2D(32, 3, padding='same', activation='relu'), 
#                 layers.MaxPooling2D(), 
#                 layers.Conv2D(64, 3, padding='same', activation='relu'), 
#                 layers.MaxPooling2D(), 
#                 layers.Flatten(), 
#                 layers.Dense(128, activation='relu'), 
#                 layers.Dense(10) 
#             ]) 
#             model.compile(optimizer='adam', loss=loss, metrics=['accuracy'])
#             history = model.fit(train, validation_data=test, epochs=epochs)
#             test_acc = history.history['val_accuracy'] 
#             print(test_acc)
#             if test_acc[-1] > best_test_accuracy:
#                 best_model = model
#                 best_test_accuracy = test_acc[-1]
#                 best_loss = loss
#                 best_epochs = epochs
# except KeyboardInterrupt:
#     pass
# finally:
#     print(f"Best validation accuracy achieved: {best_test_accuracy}")
#     # Dump best model just in case of accidental loss
#     import pickle
#     try:
#         with open ("best_model", "w") as f:
#             pickle.dump((best_model, best_loss, best_epochs), f)
#     except:
#         print("ERROR IN DUMPING")
#         with open("best_model", "w") as f:
#             pickle.dump(best_model, f)

# %%
def make_model():
    inputs = keras.Input(shape=(224,224, 3))

    # Entry block
    x = layers.Rescaling(1.0 / 255)(inputs)
    x = layers.RandomFlip("horizontal")(x) # Helps introduce variety to expand dataset & reduce overfitting
    x = layers.RandomRotation(0.1)(x)
    x = layers.Conv2D(128, 3, strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [256, 512, 728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.25)(x)
    # We specify activation=None so as to return logits
    outputs = layers.Dense(10, activation=None)(x)
    return keras.Model(inputs, outputs)

# %%
model = make_model()
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
history = model.fit(train, validation_data=test, epochs=60)
# Out:
# Epoch 1/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2439 - loss: 2.2126
# E0000 00:00:1774355999.950290    4495 meta_optimizer.cc:967] remapper failed: INVALID_ARGUMENT: Mutation::Apply error: fanout 'StatefulPartitionedCall/functional_2_1/activation_21_1/Relu' exist for missing node 'StatefulPartitionedCall/functional_2_1/add_6_1/Add'.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 387s 2s/step - accuracy: 0.2815 - loss: 2.0722 - val_accuracy: 0.1107 - val_loss: 2.3958
# Epoch 2/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 560s 3s/step - accuracy: 0.3949 - loss: 1.7271 - val_accuracy: 0.1107 - val_loss: 3.1345
# Epoch 3/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 558s 3s/step - accuracy: 0.4470 - loss: 1.5619 - val_accuracy: 0.1347 - val_loss: 2.6757
# Epoch 4/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 556s 3s/step - accuracy: 0.5204 - loss: 1.3922 - val_accuracy: 0.4820 - val_loss: 1.4628
# Epoch 5/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 502s 3s/step - accuracy: 0.5541 - loss: 1.2891 - val_accuracy: 0.4267 - val_loss: 1.7429
# Epoch 6/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 563s 3s/step - accuracy: 0.5996 - loss: 1.1752 - val_accuracy: 0.3760 - val_loss: 2.6475
# Epoch 7/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 555s 3s/step - accuracy: 0.6316 - loss: 1.0870 - val_accuracy: 0.4420 - val_loss: 2.2586
# Epoch 8/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 537s 3s/step - accuracy: 0.6535 - loss: 1.0090 - val_accuracy: 0.5573 - val_loss: 1.3674
# Epoch 9/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.6781 - loss: 0.9639 - val_accuracy: 0.5967 - val_loss: 1.4493
# Epoch 10/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 565s 3s/step - accuracy: 0.6764 - loss: 0.9319 - val_accuracy: 0.4500 - val_loss: 1.8775
# Epoch 11/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.7074 - loss: 0.8659 - val_accuracy: 0.5120 - val_loss: 1.7880
# Epoch 12/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.7276 - loss: 0.8118 - val_accuracy: 0.4940 - val_loss: 1.6921
# Epoch 13/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 565s 3s/step - accuracy: 0.7288 - loss: 0.8036 - val_accuracy: 0.5320 - val_loss: 1.7847
# Epoch 14/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 539s 3s/step - accuracy: 0.7556 - loss: 0.7245 - val_accuracy: 0.5780 - val_loss: 1.6529
# Epoch 15/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 544s 3s/step - accuracy: 0.7571 - loss: 0.7105 - val_accuracy: 0.5953 - val_loss: 1.5731
# Epoch 16/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 548s 3s/step - accuracy: 0.7766 - loss: 0.6573 - val_accuracy: 0.5733 - val_loss: 1.4267
# Epoch 17/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 543s 3s/step - accuracy: 0.7910 - loss: 0.6375 - val_accuracy: 0.5227 - val_loss: 1.8748
# Epoch 18/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 523s 3s/step - accuracy: 0.7857 - loss: 0.6290 - val_accuracy: 0.6607 - val_loss: 1.2271
# Epoch 19/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 533s 3s/step - accuracy: 0.7853 - loss: 0.6336 - val_accuracy: 0.6593 - val_loss: 1.0378
# Epoch 20/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 545s 3s/step - accuracy: 0.8015 - loss: 0.5687 - val_accuracy: 0.7020 - val_loss: 0.9714
# Epoch 21/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 561s 3s/step - accuracy: 0.8057 - loss: 0.5769 - val_accuracy: 0.6040 - val_loss: 1.4354
# Epoch 22/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.8290 - loss: 0.5169 - val_accuracy: 0.5613 - val_loss: 1.8466
# Epoch 23/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 575s 3s/step - accuracy: 0.8316 - loss: 0.4874 - val_accuracy: 0.6340 - val_loss: 1.6174
# Epoch 24/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 539s 3s/step - accuracy: 0.8187 - loss: 0.5453 - val_accuracy: 0.7193 - val_loss: 1.0193
# Epoch 25/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 534s 3s/step - accuracy: 0.8189 - loss: 0.5203 - val_accuracy: 0.6013 - val_loss: 1.4928
# Epoch 26/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 541s 3s/step - accuracy: 0.8499 - loss: 0.4481 - val_accuracy: 0.6680 - val_loss: 1.2303
# Epoch 27/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 540s 3s/step - accuracy: 0.8575 - loss: 0.4184 - val_accuracy: 0.6707 - val_loss: 1.2152
# Epoch 28/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 553s 3s/step - accuracy: 0.8427 - loss: 0.4575 - val_accuracy: 0.6813 - val_loss: 1.2603
# Epoch 29/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 531s 3s/step - accuracy: 0.8554 - loss: 0.4261 - val_accuracy: 0.5873 - val_loss: 1.6776
# Epoch 30/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 560s 3s/step - accuracy: 0.8665 - loss: 0.3977 - val_accuracy: 0.7327 - val_loss: 0.9744
# Epoch 31/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 532s 3s/step - accuracy: 0.8547 - loss: 0.4367 - val_accuracy: 0.7160 - val_loss: 0.9806
# Epoch 32/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 540s 3s/step - accuracy: 0.8853 - loss: 0.3552 - val_accuracy: 0.6980 - val_loss: 1.0237
# Epoch 33/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 552s 3s/step - accuracy: 0.8857 - loss: 0.3262 - val_accuracy: 0.7333 - val_loss: 1.0158
# Epoch 34/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 545s 3s/step - accuracy: 0.8695 - loss: 0.3842 - val_accuracy: 0.7600 - val_loss: 0.8783
# Epoch 35/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 546s 3s/step - accuracy: 0.8947 - loss: 0.3179 - val_accuracy: 0.6853 - val_loss: 1.4126
# Epoch 36/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 546s 3s/step - accuracy: 0.9070 - loss: 0.2898 - val_accuracy: 0.6800 - val_loss: 1.3429
# Epoch 37/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 554s 3s/step - accuracy: 0.8655 - loss: 0.3989 - val_accuracy: 0.7093 - val_loss: 1.2133
# Epoch 38/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 543s 3s/step - accuracy: 0.9097 - loss: 0.2737 - val_accuracy: 0.6320 - val_loss: 1.4739
# Epoch 39/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 566s 3s/step - accuracy: 0.8970 - loss: 0.3042 - val_accuracy: 0.6947 - val_loss: 1.1977
# Epoch 40/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 547s 3s/step - accuracy: 0.9103 - loss: 0.2624 - val_accuracy: 0.7227 - val_loss: 1.0898
# Epoch 41/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 539s 3s/step - accuracy: 0.9105 - loss: 0.2517 - val_accuracy: 0.7040 - val_loss: 1.3018
# Epoch 42/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 540s 3s/step - accuracy: 0.9244 - loss: 0.2259 - val_accuracy: 0.7313 - val_loss: 1.1197
# Epoch 43/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 550s 3s/step - accuracy: 0.9248 - loss: 0.2154 - val_accuracy: 0.7260 - val_loss: 1.2701
# Epoch 44/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 580s 3s/step - accuracy: 0.9194 - loss: 0.2441 - val_accuracy: 0.7293 - val_loss: 1.1114
# Epoch 45/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 537s 3s/step - accuracy: 0.9274 - loss: 0.2171 - val_accuracy: 0.7473 - val_loss: 1.0063
# Epoch 46/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 540s 3s/step - accuracy: 0.9019 - loss: 0.2918 - val_accuracy: 0.7133 - val_loss: 1.0001
# Epoch 47/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 588s 3s/step - accuracy: 0.9370 - loss: 0.1926 - val_accuracy: 0.7393 - val_loss: 1.0361
# Epoch 48/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 565s 3s/step - accuracy: 0.9490 - loss: 0.1581 - val_accuracy: 0.7407 - val_loss: 1.0109
# Epoch 49/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 614s 3s/step - accuracy: 0.9295 - loss: 0.2137 - val_accuracy: 0.7180 - val_loss: 1.2847
# Epoch 50/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 533s 3s/step - accuracy: 0.9217 - loss: 0.2191 - val_accuracy: 0.6567 - val_loss: 1.6026
# Epoch 51/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 553s 3s/step - accuracy: 0.9459 - loss: 0.1561 - val_accuracy: 0.7333 - val_loss: 1.2677
# Epoch 52/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 439s 3s/step - accuracy: 0.9303 - loss: 0.2040 - val_accuracy: 0.7127 - val_loss: 1.4079
# Epoch 53/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 365s 2s/step - accuracy: 0.9126 - loss: 0.2574 - val_accuracy: 0.7427 - val_loss: 1.0630
# Epoch 54/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 348s 2s/step - accuracy: 0.9259 - loss: 0.2278 - val_accuracy: 0.7260 - val_loss: 1.1709
# Epoch 55/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 366s 2s/step - accuracy: 0.9505 - loss: 0.1478 - val_accuracy: 0.7760 - val_loss: 0.8469
# Epoch 56/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 367s 2s/step - accuracy: 0.9434 - loss: 0.1641 - val_accuracy: 0.7187 - val_loss: 1.4286
# Epoch 57/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 383s 2s/step - accuracy: 0.9417 - loss: 0.1842 - val_accuracy: 0.7640 - val_loss: 0.9833
# Epoch 58/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 350s 2s/step - accuracy: 0.9530 - loss: 0.1421 - val_accuracy: 0.6620 - val_loss: 2.3324
# Epoch 59/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 367s 2s/step - accuracy: 0.9349 - loss: 0.2005 - val_accuracy: 0.7553 - val_loss: 0.9818
# Epoch 60/60
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 357s 2s/step - accuracy: 0.9436 - loss: 0.1630 - val_accuracy: 0.7593 - val_loss: 0.9330

# %%
acc = history.history['accuracy'] 
val_acc = history.history['val_accuracy'] 
loss = history.history['loss'] 
val_loss = history.history['val_loss'] 
epochs_range = range(60) 
plt.figure(figsize=(8, 8)) 
plt.subplot(1, 2, 1) 
plt.plot(epochs_range, acc, label='Training Accuracy') 
plt.plot(epochs_range, val_acc, label='Validation Accuracy') 
plt.legend(loc='lower right') 
plt.title('Training and Validation Accuracy for Sparse Categorical Crossentropy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy for Sparse Categorical Crossentropy')

# %%
# model = make_model()
# model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True), metrics=['accuracy'])
# history = model.fit(train, validation_data=test, epochs=50)

# acc = history.history['accuracy'] 
# val_acc = history.history['val_accuracy'] 
# loss = history.history['loss'] 
# val_loss = history.history['val_loss'] 
# epochs_range = range(100) 
# plt.figure(figsize=(8, 8)) 
# plt.subplot(1, 2, 1) 
# plt.plot(epochs_range, acc, label='Training Accuracy') 
# plt.plot(epochs_range, val_acc, label='Validation Accuracy') 
# plt.legend(loc='lower right') 
# plt.title('Training and Validation Accuracy for Categorical Crossentropy') 
# plt.subplot(1, 2, 2) 
# plt.plot(epochs_range, loss, label='Training Loss') 
# plt.plot(epochs_range, val_loss, label='Validation Loss') 
# plt.legend(loc='upper right') 
# plt.title('Training and Validation Loss') 
# plt.show()

# %%
# train = tf.keras.utils.image_dataset_from_directory( 
# 	train_dir, 
#     validation_split=0.3, 
# 	subset="training", 
# 	seed=55,
# 	image_size=(224, 224), 
# 	batch_size=32,
#     label_mode='categorical') 

# test = tf.keras.utils.image_dataset_from_directory( 
# 	train_dir, 
#     validation_split=0.2, 
# 	subset="validation", 
# 	seed=55,
# 	image_size=(224, 224), 
# 	batch_size=32,
#     label_mode='categorical')
# Out:
# Found 7500 files belonging to 10 classes.
# Using 5250 files for training.
# Found 7500 files belonging to 10 classes.
# Using 1500 files for validation.

# %%
# model = make_model()
# model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalFocalCrossentropy(from_logits=True), metrics=['accuracy'])
# history = model.fit(train, validation_data=test, epochs=50)

# acc = history.history['accuracy'] 
# val_acc = history.history['val_accuracy'] 
# loss = history.history['loss'] 
# val_loss = history.history['val_loss'] 
# epochs_range = range(100) 
# plt.figure(figsize=(8, 8)) 
# plt.subplot(1, 2, 1) 
# plt.plot(epochs_range, acc, label='Training Accuracy') 
# plt.plot(epochs_range, val_acc, label='Validation Accuracy') 
# plt.legend(loc='lower right') 
# plt.title('Training and Validation Accuracy for Categorical Focal Crossentropy') 
# plt.subplot(1, 2, 2) 
# plt.plot(epochs_range, loss, label='Training Loss') 
# plt.plot(epochs_range, val_loss, label='Validation Loss') 
# plt.legend(loc='upper right') 
# plt.title('Training and Validation Loss') 
# plt.show()
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 model = make_model()
#       2 model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalFocalCrossentropy(from_logits=True), metrics=['accuracy'])
# ----> 3 history = model.fit(train, validation_data=test, epochs=50)
#       5 acc = history.history['accuracy']
#       6 val_acc = history.history['val_accuracy']
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:399, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397 for begin_step, end_step, iterator in epoch_iterator:
#     398     callbacks.on_train_batch_begin(begin_step)
# --> 399     logs = self.train_function(iterator)
#     400     callbacks.on_train_batch_end(end_step, logs)
#     401     if self.stop_training:
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:154, in TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator(iterator)
#     150 @tf.autograph.experimental.do_not_convert
#     151 def multi_step_on_iterator(iterator):
#     152     if self.steps_per_execution == 1:
#     153         return tf.experimental.Optional.from_value(
# --> 154             one_step_on_data(iterator.get_next())
#     155         )
#     157     # the spec is set lazily during the tracing of `tf.while_loop`
#     158     empty_outputs = tf.experimental.Optional.empty(None)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:125, in TensorFlowTrainer._autoconvert_optionals.<locals>.wrapper(data)
#     117 @functools.wraps(step_func)
#     118 def wrapper(data):
#     119     converted_data = tree.map_structure(
#     120         lambda i: (
#     121             None if isinstance(i, tf.experimental.Optional) else i
#     122         ),
#     123         data,
#     124     )
# --> 125     result = step_func(converted_data)
#     126     return result
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:889, in Function._call(self, *args, **kwds)
#     886 try:
#     887   # This is the first call of __call__, so we have to initialize.
#     888   initializers = []
# --> 889   self._initialize(args, kwds, add_initializers_to=initializers)
#     890 finally:
#     891   # At this point we know that the initialization is complete (or less
#     892   # interestingly an exception was raised) so we no longer need a lock.
#     893   self._lock.release()
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:696, in Function._initialize(self, args, kwds, add_initializers_to)
#     691 self._variable_creation_config = self._generate_scoped_tracing_options(
#     692     variable_capturing_scope,
#     693     tracing_compilation.ScopeType.VARIABLE_CREATION,
#     694 )
#     695 # Force the definition of the function for these arguments
# --> 696 self._concrete_variable_creation_fn = tracing_compilation.trace_function(
#     697     args, kwds, self._variable_creation_config
#     698 )
#     700 def invalid_creator_scope(*unused_args, **unused_kwds):
#     701   """Disables variable creation."""
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:178, in trace_function(args, kwargs, tracing_options)
#     175     args = tracing_options.input_signature
#     176     kwargs = {}
# --> 178   concrete_function = _maybe_define_function(
#     179       args, kwargs, tracing_options
#     180   )
#     182 if not tracing_options.bind_graph_to_function:
#     183   concrete_function._garbage_collector.release()  # pylint: disable=protected-access
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:283, in _maybe_define_function(args, kwargs, tracing_options)
#     281 else:
#     282   target_func_type = lookup_func_type
# --> 283 concrete_function = _create_concrete_function(
#     284     target_func_type, lookup_func_context, func_graph, tracing_options
#     285 )
#     287 if tracing_options.function_cache is not None:
#     288   tracing_options.function_cache.add(
#     289       concrete_function, current_func_context
#     290   )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:310, in _create_concrete_function(function_type, type_context, func_graph, tracing_options)
#     303   placeholder_bound_args = function_type.placeholder_arguments(
#     304       placeholder_context
#     305   )
#     307 disable_acd = tracing_options.attributes and tracing_options.attributes.get(
#     308     attributes_lib.DISABLE_ACD, False
#     309 )
# --> 310 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     311     tracing_options.name,
#     312     tracing_options.python_function,
#     313     placeholder_bound_args.args,
#     314     placeholder_bound_args.kwargs,
#     315     None,
#     316     func_graph=func_graph,
#     317     add_control_dependencies=not disable_acd,
#     318     arg_names=function_type_utils.to_arg_names(function_type),
#     319     create_placeholders=False,
#     320 )
#     322 transform.apply_func_graph_transforms(traced_func_graph)
#     324 graph_capture_container = traced_func_graph.function_captures
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:1060, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1057   return x
#    1059 _, original_func = tf_decorator.unwrap(python_func)
# -> 1060 func_outputs = python_func(*func_args, **func_kwargs)
#    1062 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1063 # TensorArrays and `None`s.
#    1064 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:599, in Function._generate_scoped_tracing_options.<locals>.wrapped_fn(*args, **kwds)
#     595 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     596   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     597   # the function a weak reference to itself to avoid a reference cycle.
#     598   with OptionalXlaContext(compile_with_xla):
# --> 599     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     600   return out
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/autograph_util.py:41, in py_func_from_autograph.<locals>.autograph_handler(*args, **kwargs)
#      39 """Calls a converted version of original_func."""
#      40 try:
# ---> 41   return api.converted_call(
#      42       original_func,
#      43       args,
#      44       kwargs,
#      45       options=converter.ConversionOptions(
#      46           recursive=True,
#      47           optional_features=autograph_options,
#      48           user_requested=True,
#      49       ))
#      50 except Exception as e:  # pylint:disable=broad-except
#      51   if hasattr(e, "ag_error_metadata"):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:339, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     337 if is_autograph_artifact(f):
#     338   logging.log(2, 'Permanently allowed: %s: AutoGraph artifact', f)
# --> 339   return _call_unconverted(f, args, kwargs, options)
#     341 # If this is a partial, unwrap it and redo all the checks.
#     342 if isinstance(f, functools.partial):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:134, in TensorFlowTrainer._make_function.<locals>.one_step_on_data(data)
#     131 @tf.autograph.experimental.do_not_convert
#     132 def one_step_on_data(data):
#     133     """Runs a single training step on a batch of data."""
# --> 134     outputs = self.distribute_strategy.run(step_function, args=(data,))
#     135     outputs = reduce_per_replica(
#     136         outputs,
#     137         self.distribute_strategy,
#     138         reduction="auto",
#     139     )
#     140     return outputs
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:1673, in StrategyBase.run(***failed resolving arguments***)
#    1668 with self.scope():
#    1669   # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670   # applied when the caller is also in Eager mode.
#    1671   fn = autograph.tf_convert(
#    1672       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673   return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:3263, in StrategyExtendedV1.call_for_each_replica(self, fn, args, kwargs)
#    3261   kwargs = {}
#    3262 with self._container_strategy().scope():
# -> 3263   return self._call_for_each_replica(fn, args, kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:4061, in _DefaultDistributionExtended._call_for_each_replica(self, fn, args, kwargs)
#    4059 def _call_for_each_replica(self, fn, args, kwargs):
#    4060   with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061     return fn(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/autograph/impl/api.py:643, in do_not_convert.<locals>.wrapper(*args, **kwargs)
#     641 def wrapper(*args, **kwargs):
#     642   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643     return func(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:84, in TensorFlowTrainer.train_step(self, data)
#      81     gradients = tape.gradient(loss, trainable_weights)
#      83     # Update weights
# ---> 84     self.optimizer.apply_gradients(zip(gradients, trainable_weights))
#      85 else:
#      86     warnings.warn("The model does not have any trainable weights.")
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:462, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     460 def apply_gradients(self, grads_and_vars):
#     461     grads, trainable_variables = zip(*grads_and_vars)
# --> 462     self.apply(grads, trainable_variables)
#     463     # Return iterations for compat with tf.keras.
#     464     return self._iterations
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:501, in BaseOptimizer.apply(self, grads, trainable_variables)
#     499 if not self.built:
#     500     with backend.name_scope(self.name, caller=self):
# --> 501         self.build(trainable_variables)
#     502     self.built = True
#     503 self._check_variables_are_known(trainable_variables)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/adam.py:93, in Adam.build(self, var_list)
#      91     return
#      92 super().build(var_list)
# ---> 93 self._momentums, self._velocities = self.add_optimizer_variables(
#      94     var_list, ["momentum", "velocity"]
#      95 )
#      97 if self.amsgrad:
#      98     self._velocity_hats = self.add_optimizer_variables(
#      99         var_list, "velocity_hat"
#     100     )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:389, in BaseOptimizer.add_optimizer_variables(self, trainable_variables, name, initializer)
#     384 if not self._overwrite_variable_with_gradient(variable):
#     385     for i, (var_name, var_init) in enumerate(
#     386         zip(name_list, initializer_list)
#     387     ):
#     388         optimizer_variables[i].append(
# --> 389             self.add_variable_from_reference(
#     390                 variable,
#     391                 name=var_name,
#     392                 initializer=var_init,
#     393             )
#     394         )
#     395 else:
#     396     for i in range(len(name_list)):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/optimizer.py:35, in TFOptimizer.add_variable_from_reference(self, reference_variable, name, initializer)
#      30     colocate_var = reference_variable
#      32 with self._distribution_strategy.extended.colocate_vars_with(
#      33     colocate_var
#      34 ):
# ---> 35     return super().add_variable_from_reference(
#      36         reference_variable, name=name, initializer=initializer
#      37     )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:319, in BaseOptimizer.add_variable_from_reference(self, reference_variable, name, initializer)
#     315     sanitised_ref_name = (
#     316         str(reference_variable.name).replace("/", "_").replace(":", "_")
#     317     )
#     318     name = f"{sanitised_ref_name}_{name}"
# --> 319 return self.add_variable(
#     320     shape=reference_variable.shape,
#     321     initializer=initializer,
#     322     dtype=reference_variable.dtype,
#     323     name=name,
#     324     layout=getattr(reference_variable, "_layout", None),
#     325 )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/optimizers/base_optimizer.py:274, in BaseOptimizer.add_variable(self, shape, initializer, dtype, aggregation, layout, name)
#     272 initializer = initializers.get(initializer)
#     273 with backend.name_scope(self.name, caller=self):
# --> 274     variable = backend.Variable(
#     275         initializer=initializer,
#     276         shape=shape,
#     277         dtype=dtype,
#     278         trainable=False,
#     279         aggregation=aggregation,
#     280         layout=layout,
#     281         name=name,
#     282     )
#     283 self._track_variable(variable)
#     284 return variable
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/common/variables.py:206, in Variable.__init__(***failed resolving arguments***)
#     204 if callable(initializer):
#     205     self._shape = self._validate_shape(shape)
# --> 206     self._initialize_with_initializer(initializer)
#     207 else:
#     208     self._initialize(initializer)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:52, in Variable._initialize_with_initializer(self, initializer)
#      51 def _initialize_with_initializer(self, initializer):
# ---> 52     self._initialize(lambda: initializer(self._shape, dtype=self._dtype))
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/keras/src/backend/tensorflow/core.py:42, in Variable._initialize(self, value)
#      40     self._value = value
#      41 else:
# ---> 42     self._value = tf.Variable(
#      43         value,
#      44         dtype=self._dtype,
#      45         trainable=self.trainable,
#      46         name=self.name,
#      47         aggregation=self._map_aggregation(self.aggregation),
#      48         synchronization=self._map_synchronization(self.synchronization),
#      49     )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:200, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     197 @traceback_utils.filter_traceback
#     198 def __call__(cls, *args, **kwargs):
#     199   if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 200     variable_call = cls._variable_call(*args, **kwargs)
#     201     if variable_call is not None:
#     202       return variable_call
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:1232, in Variable._variable_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, **kwargs)
#    1230 if aggregation is None:
#    1231   aggregation = VariableAggregation.NONE
# -> 1232 return previous_getter(
#    1233     initial_value=initial_value,
#    1234     trainable=trainable,
#    1235     validate_shape=validate_shape,
#    1236     caching_device=caching_device,
#    1237     name=name,
#    1238     variable_def=variable_def,
#    1239     dtype=dtype,
#    1240     import_scope=import_scope,
#    1241     constraint=constraint,
#    1242     synchronization=synchronization,
#    1243     aggregation=aggregation,
#    1244     shape=shape,
#    1245     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1246     **kwargs
#    1247 )
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:59, in _make_getter.<locals>.getter(**kwargs)
#      58 def getter(**kwargs):
# ---> 59   return captured_getter(captured_previous, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:3976, in _DefaultDistributionContext.__init__.<locals>.creator(next_creator, **kwargs)
#    3974 def creator(next_creator, **kwargs):
#    3975   _require_strategy_scope_strategy(strategy)
# -> 3976   return next_creator(**kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:59, in _make_getter.<locals>.getter(**kwargs)
#      58 def getter(**kwargs):
# ---> 59   return captured_getter(captured_previous, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/distribute/distribute_lib.py:3976, in _DefaultDistributionContext.__init__.<locals>.creator(next_creator, **kwargs)
#    3974 def creator(next_creator, **kwargs):
#    3975   _require_strategy_scope_strategy(strategy)
# -> 3976   return next_creator(**kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:59, in _make_getter.<locals>.getter(**kwargs)
#      58 def getter(**kwargs):
# ---> 59   return captured_getter(captured_previous, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:684, in Function._initialize.<locals>.variable_capturing_scope(next_creator, **kwds)
#     682 if not enable_variable_lifting:
#     683   return next_creator(**kwds)
# --> 684 v = UnliftedInitializerVariable(
#     685     add_initializers_to=add_initializers_to, **kwds
#     686 )
#     687 created_variables.append(weakref.ref(v))
#     688 return v
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/variables.py:203, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     201   if variable_call is not None:
#     202     return variable_call
# --> 203 return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:386, in UnliftedInitializerVariable.__init__(self, initial_value, trainable, caching_device, name, dtype, constraint, add_initializers_to, synchronization, aggregation, shape, **unused_kwargs)
#     383 # Capture the handle ahead of time in order to avoid querying the shape
#     384 # of the handle which helps async execution performance
#     385 graph.capture(self._handle, shape=())
# --> 386 cond.cond(
#     387     resource_variable_ops.var_is_initialized_op(self._handle),
#     388     not_assign_fn, assign_fn)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:164, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     162 filtered_tb = None
#     163 try:
# --> 164   return fn(*args, **kwargs)
#     165 except Exception as e:
#     166   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1264, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1262 # Fallback dispatch system (dispatch v1):
#    1263 try:
# -> 1264   return dispatch_target(*args, **kwargs)
#    1265 except (TypeError, ValueError):
#    1266   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267   # TypeError, when given unexpected types.  So we need to catch both.
#    1268   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/util/deprecation.py:588, in deprecated_args.<locals>.deprecated_wrapper.<locals>.new_func(*args, **kwargs)
#     580         _PRINTED_WARNING[(func, arg_name)] = True
#     581       _log_deprecation(
#     582           'From %s: calling %s (from %s) with %s is deprecated and will '
#     583           'be removed %s.\nInstructions for updating:\n%s',
#    (...)    586           'in a future version' if date is None else ('after %s' % date),
#     587           instructions)
# --> 588 return func(*args, **kwargs)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/cond.py:146, in cond(pred, true_fn, false_fn, strict, name, fn1, fn2)
#     144 # Always enable control flow v2 if building a function, regardless of toggle.
#     145 if util.EnableControlFlowV2(ops.get_default_graph()):
# --> 146   return cond_v2.cond_v2(pred, true_fn, false_fn, name)
#     148 with ops.name_scope(name, "cond", [pred]):
#     149   # Add the Switch to the graph.
#     150   if isinstance(pred, bool):
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/ops/cond_v2.py:90, in cond_v2(pred, true_fn, false_fn, name)
#      87 add_control_dependencies = ops.get_default_graph()._add_control_dependencies
#      88 pred = _normalize_pred(pred)
# ---> 90 true_graph = func_graph_module.func_graph_from_py_func(
#      91     true_name,
#      92     true_fn, [], {},
#      93     func_graph=util.CondBranchFuncGraph(
#      94         true_name, collections=ops.get_default_graph()._collections),  # pylint: disable=protected-access
#      95     add_control_dependencies=add_control_dependencies,
#      96     op_return_value=pred)
#      97 false_graph = func_graph_module.func_graph_from_py_func(
#      98     false_name,
#      99     false_fn, [], {},
#    (...)    102     add_control_dependencies=add_control_dependencies,
#     103     op_return_value=pred)
#     105 verify_captures(_COND, [true_graph, false_graph])
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/framework/func_graph.py:988, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#     985 else:
#     986   deps_control_manager = ops.NullContextmanager()
# --> 988 with func_graph.as_default(), deps_control_manager as deps_ctx:
#     989   current_scope = variable_scope.get_variable_scope()
#     990   default_use_resource = current_scope.use_resource
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:459, in AutomaticControlDependencies.__exit__(self, unused_type, unused_value, unused_traceback)
#     456 resource_inputs = set()
#     457 # Check for any resource inputs. If we find any, we update control_inputs
#     458 # and last_write_to_resource.
# --> 459 for inp, resource_type in _get_resource_inputs(op):
#     460   is_read = resource_type == ResourceType.READ_ONLY
#     461   input_id = ops.tensor_id(inp)
#
# File ~/551-Assignment-2/tf/lib/python3.12/site-packages/tensorflow/python/framework/auto_control_deps.py:621, in _get_resource_inputs(op)
#     618     if updated:
#     619       # Conservatively remove any resources from `reads` that are also writes.
#     620       reads = reads.difference(writes)
# --> 621     saturated = saturated and not updated
#     623 # Note: A resource handle that is not written to is treated as read-only. We
#     624 # don't have a special way of denoting an unused resource.
#     625 for t in reads:
#
# KeyboardInterrupt:

# %%
full_train = tf.keras.utils.image_dataset_from_directory( 
	train_dir, 
	image_size=(224, 224), 
	batch_size=32,
    label_mode='categorical')
